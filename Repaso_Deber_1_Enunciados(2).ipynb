# %% [markdown]
# # Review Exercises - Homework 1

# %% [markdown]
# ## Exercise 1Ana runs a fruit stand at the market and wants a quick tool to figure out howmuch a customer owes. Write a program that asks for the weight purchased (inkilos) and the price per kilo, and calculates the total to pay. You must useinput() to read the values and float() to convert them. Test your programwith kilos=12 and price_per_kilo=0.85 (the result should be 10.2).

# %% [markdown]
# ## Exercise 2A phone carrier charges a fixed rate for the first 100 GB consumed in amonth. If the customer goes over that limit, each additional GB costs 1.5times the normal rate (example: if the rate is 1 dollar per GB, it rises to1.5 dollars from GB 101 onward). Build the program that calculates the totalbill. Test it with gb_consumed=130 and price_per_gb=5.00 (the result shouldbe 725.0).

# %% [markdown]
# ## Exercise 3A restaurant collects customer ratings on a scale from 0 to 10 after everyvisit. Write a program that reads the rating and determines the servicecategory according to the table below. If the value entered is out ofrange, the program should print an error message.• Exceptional - rating >= 9.5• Very good - rating >= 8.0• Acceptable - rating >= 6.0• Poor - rating >= 4.0• Very poor - rating < 4.0Test it with rating=8.3 (the result should be "Very good").

# %% [markdown]
# ## Exercise 4A delivery company charges a base rate for the first 3 km traveled on eachdelivery. From the fourth kilometer onward, the rate per km increases 1.5times (example: if the rate is 1 dollar per km, it rises to 1.5 dollars fromkm 4 onward). The company needs a reusable function calledcalculate_delivery_cost() to use across all its orders. Test it withkm_traveled=5 and rate_per_km=3.00 (the result should be 18.0).

# %% [markdown]
# ## Exercise 5A teacher wants to record students' quiz scores one at a time. The programshould keep asking for numbers until the teacher types the word "DONE". Ifthe teacher accidentally types something that is not a number, the programshould catch the error using try/except and ignore that value withoutstopping. At the end, it should print the total sum and the average of theentered scores.Enter 8, 9, auto, 7 and DONE: the program should ignore "auto" and print"Sum: 24" and "Average: 8.0".

# %% [markdown]
# ## Exercise 6A warehouse keeps two lists of product codes: current_stock, with what iscurrently in the warehouse, and sold_this_month, with what has been sold.The manager wants to know which products are still in the warehouse andhave NOT been sold (that is, the ones that appear in current_stock but notin sold_this_month). For example, withcurrent_stock=[101,105,110,115,120,125,130] andsold_this_month=[100,105,109,115,119,125,140], the result should be[101, 110, 120, 130].

# %% [markdown]
# ## Exercise 7You are building a tag cloud for a blog and want the shortest words to showup first. Write a program that receives the sentence "Machine learningchanges everything quickly", splits it into words, and sorts them fromshortest to longest. Tip: put the words in a list and use the sortfunction.

# %% [markdown]
# ## Exercise 8A social media analyst wants to know how many times each word repeats in atweet in order to spot keywords. Write a program that receives a text andcounts how many times each word appears, using a dictionary. Example: if thetext is 'python is great python is fun python is powerful', the resultshould be {'python': 3, 'is': 3, 'great': 1, 'fun': 1, 'powerful': 1}.
